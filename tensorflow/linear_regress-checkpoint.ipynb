# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X = np.random.rand(100).astype(np.float32) 
a = 50
b = 40
Y = a * X + b # dependent variable

# %%
plt.plot(X,Y)

# %%
Y = np.vectorize(lambda y: y + np.random.normal(loc=0.0, scale=0.05))(Y)
a_var = tf.Variable(1.0)
b_var = tf.Variable(1.0)
y_var = a_var*X + b_var 

loss = tf.reduce_mean(tf.square(y_var - Y)) # reduce error cost funtion
# Define optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=0.5)
train = optimizer.minimize(loss)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 9
#       7 # Define optimizer
#       8 optimizer = tf.keras.optimizers.SGD(learning_rate=0.5)
# ----> 9 train = optimizer.minimize(loss)
#
# AttributeError: 'SGD' object has no attribute 'minimize'
